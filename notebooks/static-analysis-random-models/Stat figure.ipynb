# %%
import pickle
import networkx as nx
import numpy as np
import pandas as pd

from scipy import stats

import matplotlib.pyplot as plt

from datetime import datetime

import statsmodels.api as sm
import pylab as py

np.set_printoptions(precision=3)
np.set_printoptions(suppress=True)

# %%
myfname = 'A1'
with open(f'./{myfname}.pkl', 'rb') as fh:
    A1_loaded = pickle.load(fh)
    
myfname = 'E1'
with open(f'./{myfname}.pkl', 'rb') as fh:
    E1_loaded = pickle.load(fh)
myfname = 'A8'
with open(f'./{myfname}.pkl', 'rb') as fh:
    A8_loaded = pickle.load(fh)

# fig_loaded

# %%
ax = A1_loaded.gca()

# %%
ax.lines[0]

# %%
fig, axs = plt.subplots(nrows = 3,
                        ncols = 2,
                        figsize= (20, 20)
                       )
axs[0,0] = ax

plt.tight_layout()  # makes that labels etc. fit nicely
plt.show()

# %%
axs[0,0].lines
